# %%
string = "341 fadhil"
print(string, type(string))
integer = 1
print(integer, type(integer))
float = 33.3
print(float, type(float))
boolean =  3 > 1
print(boolean, type(boolean))
# Out:
# 341 fadhil <class 'str'>
# 1 <class 'int'>
# 33.3 <class 'float'>
# True <class 'bool'>
